# %% [markdown]
# <a href="https://colab.research.google.com/github/hruthiksiva/basic-ml-practice/blob/main/pandas_beginner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# combination power query, pivot tables, xl formulas

# %%
import pandas as pd
import numpy as np

# %%
df0 = pd.read_excel('hello.xlsx',sheet_name='sheet1')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/warmup-data/coffee.csv')
df
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
df2 = pd.DataFrame(
    {
        "a":['1','2','3'],
        "b":['4','5','6']
    }
)
df2
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df3 = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],columns=['a','b','c'],index=['a',2,3])
df3
# Out:
#    a  b  c
# a  1  2  3
# 2  4  5  6
# 3  7  8  9

# %%
df3.head()
# Out:
#    a  b  c
# a  1  2  3
# 2  4  5  6
# 3  7  8  9

# %%
df3.tail()
# Out:
#    a  b  c
# a  1  2  3
# 2  4  5  6
# 3  7  8  9

# %%
df0.to_excel('')
df0.to_csv('')
df0.to_parquet('')
df0.to_feather('')

# %%
display(df2)
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %% [markdown]
# loc iloc.
#
# df2 [ rows,columns]

# %%
df.loc[0]
df.loc[[0,1]]
df.loc[0:1]
# Out:
#          Date Company        Person Name  Room number
# 0  1-Jan-2022  Avamba  Anatole Ridehalgh       4008.0
# 1  1-Jan-2022    Fatz    Aldrich McKevin       2002.0

# %%
df.loc[0:15,['Day']]
# Out:
#           Day
# 0      Monday
# 1      Monday
# 2     Tuesday
# 3     Tuesday
# 4   Wednesday
# 5   Wednesday
# 6    Thursday
# 7    Thursday
# 8      Friday
# 9      Friday
# 10   Saturday
# 11   Saturday
# 12     Sunday
# 13     Sunday

# %%
df.loc[0:25,['Day','Coffee Type']]
# Out:
#           Day Coffee Type
# 0      Monday    Espresso
# 1      Monday       Latte
# 2     Tuesday    Espresso
# 3     Tuesday       Latte
# 4   Wednesday    Espresso
# 5   Wednesday       Latte
# 6    Thursday    Espresso
# 7    Thursday       Latte
# 8      Friday    Espresso
# 9      Friday       Latte
# 10   Saturday    Espresso
# 11   Saturday       Latte
# 12     Sunday    Espresso
# 13     Sunday       Latte

# %%
df.index = df["Day"]
df.loc['Monday']
# Out:
#            Day Coffee Type  Units Sold
# Day
# Monday  Monday    Espresso          25
# Monday  Monday       Latte          15

# %%
df.loc[5,'Units Sold'] = 3
df
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte           3
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
df.loc[5:8,'Units Sold'] = 3
df
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte           3
# 6    Thursday    Espresso           3
# 7    Thursday       Latte           3
# 8      Friday    Espresso           3
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %% [markdown]
# at function

# %%
df.at[0,"Units Sold"]
# Out:
# 25

# %%
df.iat[0,0]
# Out:
# 'Monday'

# %%
df.at[0,"Units Sold"]
# Out:
# 25

# %%
df['Coffee Type']
# Out:
# 0     Espresso
# 1        Latte
# 2     Espresso
# 3        Latte
# 4     Espresso
# 5        Latte
# 6     Espresso
# 7        Latte
# 8     Espresso
# 9        Latte
# 10    Espresso
# 11       Latte
# 12    Espresso
# 13       Latte
# Name: Coffee Type, dtype: object

# %%
df.Day
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %% [markdown]
# sorting

# %%
df.sort_values("Units Sold",ascending=False)
# Out:
#           Day Coffee Type  Units Sold
# 5   Wednesday       Latte           3
# 6    Thursday    Espresso           3
# 7    Thursday       Latte           3
# 8      Friday    Espresso           3
# 1      Monday       Latte          15
# 3     Tuesday       Latte          20
# 0      Monday    Espresso          25
# 2     Tuesday    Espresso          30
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
df.sort_values(["Units Sold","Coffee Type"],ascending=[0,1])
# Out:
#           Day Coffee Type  Units Sold
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 2     Tuesday    Espresso          30
# 0      Monday    Espresso          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          15
# 6    Thursday    Espresso           3
# 8      Friday    Espresso           3
# 5   Wednesday       Latte           3
# 7    Thursday       Latte           3

# %% [markdown]
# iterate through rows

# %%
for index,col in df.iterrows():
  print(str(index) + " " + str(col))
# Out:
# 0 Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object
# 1 Day            Monday
# Coffee Type     Latte
# Units Sold         15
# Name: 1, dtype: object
# 2 Day             Tuesday
# Coffee Type    Espresso
# Units Sold           30
# Name: 2, dtype: object
# 3 Day            Tuesday
# Coffee Type      Latte
# Units Sold          20
# Name: 3, dtype: object
# 4 Day            Wednesday
# Coffee Type     Espresso
# Units Sold            35
# Name: 4, dtype: object
# 5 Day            Wednesday
# Coffee Type        Latte
# Units Sold             3
# Name: 5, dtype: object
# 6 Day            Thursday
# Coffee Type    Espresso
# Units Sold            3
# Name: 6, dtype: object
# 7 Day            Thursday
# Coffee Type       Latte
# Units Sold            3
# Name: 7, dtype: object
# 8 Day              Friday
# Coffee Type    Espresso
# Units Sold            3
# Name: 8, dtype: object
# 9 Day            Friday
# Coffee Type     Latte
# ...

# %%
bios = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/bios.csv')

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.tail()
# Out:
#         athlete_id                 name   born_date        born_city  \
# 145495      149222    Polina Luchnikova  2002-01-30            Serov
# 145496      149223  Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224      Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225       André Foussard  1899-05-19            Niort
# 145499      149814        Bill Phillips  1913-07-15     Dulwich Hill
#
#             born_region born_country        NOC  height_cm  weight_kg  \
# 145495       Sverdlovsk          RUS        ROC      167.0       61.0
# 145496           Moskva          RUS        ROC      168.0       65.0
# 145497      Arkhangelsk          RUS        ROC      163.0       55.0
# 145498      Deux-Sèvres          FRA     France      166.0        NaN
# 145499  New South Wales          AUS  Australia        NaN        NaN
#
#          died_date
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498  1986-03-18
# 145499  2003-10-20

# %%
bios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.1+ MB

# %%
bios.loc[bios['height_cm']>180]
# Out:
#         athlete_id               name   born_date        born_city  \
# 1                2     Arnaud Boetsch  1969-04-01           Meulan
# 2                3       Jean Borotra  1898-08-13         Biarritz
# 5                6  Nicolas Chatelain  1970-01-13           Amiens
# 16              17         Guy Forget  1965-01-04       Casablanca
# 25              26      Henri Leconte  1963-07-04          Lillers
# ...            ...                ...         ...              ...
# 145465      149192  Stanislav Galiyev  1992-01-17  Moskva (Moscow)
# 145466      149193     Mikkel Aagaard  1995-10-18    Frederikshavn
# 145468      149195  Justin Abdelkader  1987-02-25         Muskegon
# 145473      149200     Toms Andersons  1993-11-25             Rīga
# 145494      149221      George Wright  1890-07-21          Toronto
#
#                  born_region born_country            NOC  height_cm  \
# 1                   Yvelines          FRA         France      183.0
# ...

# %%
bios.loc[bios['height_cm']>200,['name','height_cm']]
# Out:
#                       name  height_cm
# 1080        Bozhil Lozanov      208.0
# 1673      Alexis Rubalcaba      204.0
# 2647         Milan Šrejber      203.0
# 2827    Nik'oloz Deriugini      206.0
# 2832         Elşad Qadaşev      205.0
# ...                    ...        ...
# 143784  Daniel Miklasevich      203.0
# 143833  Garrett Muagututia      205.0
# 143834         Kyle Ensing      201.0
# 143835         Mitch Stahl      203.0
# 143919   Emerson Rodríguez      204.0
#
# [1219 rows x 2 columns]

# %%
bios[bios['height_cm']>220]
# Out:
#         athlete_id             name   born_date       born_city  \
# 5673          5696   Gunther Behnke  1963-01-19      Leverkusen
# 5781          5804   Tommy Burleson  1952-02-24       Crossnore
# 6978          7013  Arvydas Sabonis  1964-12-19          Kaunas
# 89070        89782         Yao Ming  1980-09-12  Xuhui District
# 89075        89787   Roberto Dueñas  1975-11-01          Madrid
# 120266      122147     Zhang Zhaoxu  1987-11-18         Binzhou
#
#                 born_region born_country                         NOC  \
# 5673    Nordrhein-Westfalen          GER                     Germany
# 5781         North Carolina          USA               United States
# 6978                 Kaunas          LTU      Lithuania Soviet Union
# 89070              Shanghai          CHN  People's Republic of China
# 89075                Madrid          ESP                       Spain
# 120266             Shandong          CHN  People's Republic of China
#
# ...

# %%
bios[bios['height_cm']>220][['name','height_cm']]
# Out:
#                    name  height_cm
# 5673     Gunther Behnke      221.0
# 5781     Tommy Burleson      223.0
# 6978    Arvydas Sabonis      223.0
# 89070          Yao Ming      226.0
# 89075    Roberto Dueñas      221.0
# 120266     Zhang Zhaoxu      221.0

# %%
bios[(bios['height_cm']>180) & (bios['weight_kg']>60)]
# Out:
#         athlete_id               name   born_date        born_city  \
# 1                2     Arnaud Boetsch  1969-04-01           Meulan
# 2                3       Jean Borotra  1898-08-13         Biarritz
# 5                6  Nicolas Chatelain  1970-01-13           Amiens
# 16              17         Guy Forget  1965-01-04       Casablanca
# 25              26      Henri Leconte  1963-07-04          Lillers
# ...            ...                ...         ...              ...
# 145464      149191    Joonas Nättinen  1991-01-03            Jämsä
# 145465      149192  Stanislav Galiyev  1992-01-17  Moskva (Moscow)
# 145466      149193     Mikkel Aagaard  1995-10-18    Frederikshavn
# 145468      149195  Justin Abdelkader  1987-02-25         Muskegon
# 145473      149200     Toms Andersons  1993-11-25             Rīga
#
#                  born_region born_country            NOC  height_cm  \
# 1                   Yvelines          FRA         France      183.0
# ...

# %% [markdown]
# Filtering Data

# %%
bios[bios['name'].str.contains("Keith",case=False)]
# Out:
#         athlete_id                  name   born_date         born_city  \
# 1897          1907          Keith Hanlon  1966-09-01               NaN
# 3505          3517         Keith Wallace  1961-03-29           Preston
# 6228          6255         Keith Hartley  1940-10-15         Vancouver
# 8898          8946           Keith Mwila  1966-01-01               NaN
# 12053        12118          Keith Hervey  1898-11-03            Fulham
# ...            ...                   ...         ...               ...
# 109900      111105     Keith Cumberpatch  1927-08-25      Christchurch
# 115973      117348       Keith Sanderson  1975-02-02          Plymouth
# 117676      119195          Duncan Keith  1983-07-16          Winnipeg
# 122121      124176        Keith Ferguson  1979-09-07              Sale
# 127310      129749  Tracy Keith-Matchitt  1990-03-30  Palmerston North
#
#               born_region born_country            NOC  height_cm  weight_kg  \
# ...

# %%
bios[bios['name'].str.contains("Keith|Patrick",case=False)]
# Out:
#         athlete_id               name   born_date              born_city  \
# 6                7      Patrick Chila  1969-11-27            Ris-Orangis
# 119            120   Patrick Wheatley  1899-01-20                Vryheid
# 319            320  Patrick De Koning  1961-04-23            Dendermonde
# 1897          1907       Keith Hanlon  1966-09-01                    NaN
# 2115          2125       Patrick Jopp  1962-01-08                    NaN
# ...            ...                ...         ...                    ...
# 143975      147633  Patrick Chinyemba  2001-01-03                    NaN
# 144172      147850      Patrick Jakob  1996-10-17  Sankt Johann in Tirol
# 144547      148239  Patrick Galbraith  1986-03-11              Haderslev
# 144565      148257    Patrick Russell  1993-01-04               Gentofte
# 145435      149158  Patrick Gasienica  1998-11-28                McHenry
#
#             born_region born_country            NOC  height_cm  weight_kg  \
# ...

# %% [markdown]
# Regex

# %%
bios[bios['name'].str.contains('son$|sen$',na=False)]
# Out:
#         athlete_id                name   born_date      born_city  \
# 37              38     Helen Aitchison  1881-12-06     Sunderland
# 92              93         Anne Gibson  1968-10-26       Dumfries
# 107            108      Anders Nielsen  1967-02-24      Cape Town
# 113            114    Julian Robertson  1969-10-09   Peterborough
# 120            121     Chris Wilkinson  1970-01-05    Southampton
# ...            ...                 ...         ...            ...
# 145419      149142      Jake Sanderson  2002-07-08      Whitefish
# 145424      149147  Jonathan Gustafson  1997-03-05        Massena
# 145441      149164        Casey Dawson  2000-08-02      Park City
# 145457      149183      Alix Wilkinson  2000-08-02  Mammoth Lakes
# 145461      149188        Kent Johnson  2002-10-18     Port Moody
#
#              born_region born_country            NOC  height_cm  weight_kg  \
# 37               England          GBR  Great Britain        NaN        NaN
# ...

# %%
bios[bios['name'].str.contains('son$|sen$',na=False,regex=False)]
# Out:
# Empty DataFrame
# Columns: [athlete_id, name, born_date, born_city, born_region, born_country, NOC, height_cm, weight_kg, died_date]
# Index: []

# %%
bios[bios['born_country'].isin(["USA"])]
# Out:
#         athlete_id               name   born_date         born_city  \
# 54              55      Monique Javer  1967-07-22        Burlingame
# 960            964   Xóchitl Escobedo  1968-09-17       West Covina
# 961            965  Angélica Gavaldón  1973-10-03         El Centro
# 1231          1238     Bert Schneider  1897-07-01         Cleveland
# 1345          1352         Laura Berg  1975-01-06  Santa Fe Springs
# ...            ...                ...         ...               ...
# 145445      149168     Kristen Santos  1994-11-02         Fairfield
# 145446      149169   Corinne Stoddard  2001-08-15           Seattle
# 145454      149180      Anna Hoffmann  2000-03-28           Madison
# 145457      149183     Alix Wilkinson  2000-08-02     Mammoth Lakes
# 145468      149195  Justin Abdelkader  1987-02-25          Muskegon
#
#         born_region born_country            NOC  height_cm  weight_kg  \
# 54       California          USA  Great Britain      177.0       64.0
# ...

# %%
bios[bios['born_country'].isin(["USA","FRA"])]
# Out:
#         athlete_id                   name   born_date      born_city  \
# 0                1  Jean-François Blanchy  1886-12-12       Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01         Meulan
# 2                3           Jean Borotra  1898-08-13       Biarritz
# 3                4        Jacques Brugnon  1895-05-11    Paris VIIIe
# 5                6      Nicolas Chatelain  1970-01-13         Amiens
# ...            ...                    ...         ...            ...
# 145454      149180          Anna Hoffmann  2000-03-28        Madison
# 145457      149183         Alix Wilkinson  2000-08-02  Mammoth Lakes
# 145467      149194            Elisa Nakab  1998-05-08       Briançon
# 145468      149195      Justin Abdelkader  1987-02-25       Muskegon
# 145498      149225         André Foussard  1899-05-19          Niort
#
#                  born_region born_country            NOC  height_cm  \
# 0                    Gironde          FRA         France        NaN
# ...

# %%
bios[bios['name'].str.startswith("Keith")]
# Out:
#         athlete_id               name   born_date     born_city  \
# 1897          1907       Keith Hanlon  1966-09-01           NaN
# 3505          3517      Keith Wallace  1961-03-29       Preston
# 6228          6255      Keith Hartley  1940-10-15     Vancouver
# 8898          8946        Keith Mwila  1966-01-01           NaN
# 12053        12118       Keith Hervey  1898-11-03        Fulham
# ...            ...                ...         ...           ...
# 99921       100722       Keith Carney  1970-02-03    Providence
# 102227      103168      Keith Beavers  1983-02-09        London
# 109900      111105  Keith Cumberpatch  1927-08-25  Christchurch
# 115973      117348    Keith Sanderson  1975-02-02      Plymouth
# 122121      124176     Keith Ferguson  1979-09-07          Sale
#
#              born_region born_country            NOC  height_cm  weight_kg  \
# 1897                 NaN          NaN        Ireland        NaN        NaN
# ...

# %% [markdown]
# query

# %%
bios.query('born_city == "London"')
# Out:
#         athlete_id                name   born_date born_city born_region  \
# 62              63       Jo Muggeridge  1969-04-03    London     England
# 63              64        Mabel Parton  1881-07-22    London     England
# 110            111        Nick Ponting  1966-09-13    London     England
# 568            570      Mark Blenkarne  1957-10-07    London     England
# 1219          1226        Casey Patton  1974-11-21    London     Ontario
# ...            ...                 ...         ...       ...         ...
# 143563      147216         Alie Rusher  1996-05-24    London     England
# 144063      147729    Lotte Wubben-Moy  1999-01-11    London     England
# 144228      147914   Kristen Bujnowski  1992-03-14    London     Ontario
# 144280      147966        Ella Shelton  1998-01-19    London     Ontario
# 144811      148512  Benjamin Alexander  1983-05-08    London     England
#
#        born_country            NOC  height_cm  weight_kg   died_date
# ...

# %% [markdown]
# adding and removing columns

# %%
df.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
df['price'] = 4.99
df
# Out:
#           Day Coffee Type  Units Sold  price
# 0      Monday    Espresso          25   4.99
# 1      Monday       Latte          15   4.99
# 2     Tuesday    Espresso          30   4.99
# 3     Tuesday       Latte          20   4.99
# 4   Wednesday    Espresso          35   4.99
# 5   Wednesday       Latte           3   4.99
# 6    Thursday    Espresso           3   4.99
# 7    Thursday       Latte           3   4.99
# 8      Friday    Espresso           3   4.99
# 9      Friday       Latte          35   4.99
# 10   Saturday    Espresso          45   4.99
# 11   Saturday       Latte          35   4.99
# 12     Sunday    Espresso          45   4.99
# 13     Sunday       Latte          35   4.99

# %%
df = df.applymap(lambda x: 0 if x == 'NO' else 1)

# %%
df['row_sum'] = df.sum(axis=1)  # Sum for each row
df.loc['col_sum'] = df.sum(axis=0)

# %%
cpu_mean = df_cpu.loc[:,"values"].mean()

# %%
for metrics in df['Metrics'].tolist():
    print(metrics)

# %%
for metrics in df['Metrics'].unique():
    print(metrics)

# %%
#sort a dictionary

health = dict(sorted(health.items(), key=lambda item: item[1]))

# %%
for genres in df['genre']:
  # Skip NaN values
  if isinstance(genres, str):
    for g in genres.split(','):
      print(g)

# %%
df = df.dropna()
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dbf26b6f1420> in <cell line: 1>()
# ----> 1 df = df.dropna()
#       2 df
#
# NameError: name 'df' is not defined

# %%
df = df[['id','title','tags']]

# %%
df = df.drop(columns=['B', 'D'])

# %%
# Specify the columns to drop
columns_to_drop = ['column4', 'column5']

# Drop the specified columns
df = df.drop(columns=columns_to_drop)

# %%
# Specify the columns to keep
columns_to_keep = ['column1', 'column2', 'column3']

# Create a new DataFrame with only the specified columns
df = df[columns_to_keep]
